# %%
import astropy
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from astropy.io import ascii
from matplotlib.ticker import ScalarFormatter
import matplotlib.ticker as ticker
import math

# %matplotlib inline

data = ascii.read("tobin-sun-bsw-meta-2-16.dat")

#print data
#print data['Name','Tbol']

#print data['Lbol','Tbol']

fig=plt.figure(figsize=(10,7))
ax = fig.add_subplot(111)
#ax.set_xlim(0,71.0)
#ax.set_ylim(-15,20)

lin1=ax.plot(data['bsw'],data['Tant'],color='black',linestyle='steps')
ax.tick_params('both', which='major', length=15, width=1, pad=15)
ax.tick_params('both', which='minor', length=7.5, width=1, pad=15)

ticks_font = mpl.font_manager.FontProperties(size=16, weight='normal', stretch='normal')
#for label in (ax.get_xticklabels() + ax.get_yticklabels()):
#            label.set_fontproperties(ticks_font)
#for axis in [ax.xaxis, ax.yaxis]:
#    axis.set_major_formatter(ScalarFormatter())
#    ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y,pos: ('{{:.{:1d}f}}'.format(int(np.maximum(-np.log10(y),0)))).format(y)))
for axis in ['top','bottom','left','right']:
   ax.spines[axis].set_linewidth(2)

ax.set_ylabel('L$_{bol}$ (L$_{\odot}$)', fontsize=18)
ax.set_xlabel('T$_{bol}$ (K)', fontsize=18)

# %%
dTant=np.zeros(int(len(data['Tant'])/2)-1)
bsw=np.zeros(int(len(data['Tant'])/2)-1)
num=0
for i in range(2,len(data['Tant'])-1,2):
   #print(data['bsw'][i])
   dTant[num]=data['Tant'][i]-data['Tant'][i+1]
   bsw[num]=data['bsw'][i]
   num=num+1

#for i in range(1,len(data['Tant'])-1,2):
#   #print(data['bsw'][i])
#   dTant[i]=-1.0*(data['Tant'][i])+data['Tant'][i-1]
#   bsw[i]=data['bsw'][i]


dTave=np.average(dTant)
sigma_dTave=np.std(dTant)
print("Average Tant: ",dTave," +/- ",sigma_dTave)

print(dTant)
fig=plt.figure(figsize=(10,7))
ax = fig.add_subplot(111)
#ax.set_xlim(0,71.0)
#ax.set_ylim(-5,5)

lin1=ax.plot(bsw+0.5,dTant,color='black',linestyle='steps')
ax.tick_params('both', which='major', length=15, width=1, pad=15)
ax.tick_params('both', which='minor', length=7.5, width=1, pad=15)

ticks_font = mpl.font_manager.FontProperties(size=16, weight='normal', stretch='normal')
#for label in (ax.get_xticklabels() + ax.get_yticklabels()):
#            label.set_fontproperties(ticks_font)
#for axis in [ax.xaxis, ax.yaxis]:
#    axis.set_major_formatter(ScalarFormatter())
#    ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y,pos: ('{{:.{:1d}f}}'.format(int(np.maximum(-np.log10(y),0)))).format(y)))
for axis in ['top','bottom','left','right']:
   ax.spines[axis].set_linewidth(2)

ax.set_ylabel('$\Delta$T$_{ant}$', fontsize=18)
ax.set_xlabel('N_bsw', fontsize=18)
# Out:
# Average Tant:  260.020192982  +/-  15.274132507
# [ 289.184  267.189  256.204  245.184  221.998  267.931  262.51   302.87
#   246.119  234.326  270.26   254.389  248.062  263.306  242.451  237.5
#   282.077  263.554  261.801  273.211  243.397  231.125  269.515  267.174
#   266.905  263.692  250.202  272.46   278.984  264.834  254.891  249.373
#   247.131  276.64   284.113  272.186  263.36   240.85   235.665  262.846
#   280.477  277.661  266.896  246.432  245.834  271.038  254.352  255.471
#   257.609  253.329  248.528  271.397  263.746  269.788  267.687  255.319
#   250.118]
